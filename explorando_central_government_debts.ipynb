# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pltb

# %% [markdown]
# # Entendendo o Data Set central_government_debt
#
#
# - O Indicador:
# Média anual da dívida do governo central (porcentagem do PIB)
#
# Ou seja os valores estão em % do PIB

# %%
df_DividaGovCentr = pd.read_csv('central_government_debt.csv', sep=',', encoding='latin1')

# %%
df_DividaGovCentr.head()
# Out:
#           country_name                                     indicator_name  \
# 0          Afghanistan  Annual average of central government debt (Per...
# 1              Albania  Annual average of central government debt (Per...
# 2              Algeria  Annual average of central government debt (Per...
# 3               Angola  Annual average of central government debt (Per...
# 4  Antigua and Barbuda  Annual average of central government debt (Per...
#
#    1950  1951  1952  1953  1954  1955  1956  1957  ...       2013        2014  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   6.904479    8.700291
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  65.530002   70.030002
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   7.093511    7.658320
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  33.149104   39.809857
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  95.791048  101.369132
#
# ...

# %%
#Qtde de linhas

qtde_linhas = len(df_DividaGovCentr)
len(df_DividaGovCentr)
# Out:
# 173

# %%
# Formato da Tabela

df_DividaGovCentr.shape
# Out:
# (173, 75)

# %%
# Nome das Colunas

df_DividaGovCentr.columns
# Out:
# Index(['country_name', 'indicator_name', '1950', '1951', '1952', '1953',
#        '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# Informações (.info)

df_DividaGovCentr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 75 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_name    173 non-null    object
#  1   indicator_name  173 non-null    object
#  2   1950            30 non-null     float64
#  3   1951            32 non-null     float64
#  4   1952            32 non-null     float64
#  5   1953            32 non-null     float64
#  6   1954            33 non-null     float64
#  7   1955            33 non-null     float64
#  8   1956            33 non-null     float64
#  9   1957            33 non-null     float64
#  10  1958            32 non-null     float64
#  11  1959            33 non-null     float64
#  12  1960            35 non-null     float64
#  13  1961            36 non-null     float64
#  14  1962            36 non-null     float64
#  15  1963            41 non-null     float64
#  16  1964            43 non-null     float64
# ...

# %%
# Traz verdadeiro ou falsa, para casos nulos.
# Nulo == 1 

df_DividaGovCentr.isnull()
# Out:
#      country_name  indicator_name  1950  1951  1952  1953  1954  1955  1956  \
# 0           False           False  True  True  True  True  True  True  True
# 1           False           False  True  True  True  True  True  True  True
# 2           False           False  True  True  True  True  True  True  True
# 3           False           False  True  True  True  True  True  True  True
# 4           False           False  True  True  True  True  True  True  True
# ..            ...             ...   ...   ...   ...   ...   ...   ...   ...
# 168         False           False  True  True  True  True  True  True  True
# 169         False           False  True  True  True  True  True  True  True
# 170         False           False  True  True  True  True  True  True  True
# 171         False           False  True  True  True  True  True  True  True
# 172         False           False  True  True  True  True  True  True  True
#
# ...

# %%
# Qtde de nulos por coluna.

qtde_NulosPorColuna = df_DividaGovCentr.isnull().sum()
df_DividaGovCentr.isnull().sum()
# Out:
# country_name        0
# indicator_name      0
# 1950              143
# 1951              141
# 1952              141
#                  ...
# 2018                3
# 2019                4
# 2020                5
# 2021                8
# 2022               12
# Length: 75, dtype: int64

# %%
qtdeOrdenada_NulosPorColuna = qtde_NulosPorColuna.sort_values(ascending=False)
qtdeOrdenada_NulosPorColuna
# Out:
# 1950              143
# 1958              141
# 1951              141
# 1952              141
# 1953              141
#                  ...
# 2016                2
# 2017                2
# 2012                2
# indicator_name      0
# country_name        0
# Length: 75, dtype: int64

# %% [markdown]
# ### Anotações sobre amostra.
#
# - Tirar uma amostra com os possíveis 30 países que tem mais informações.

# %%
# Out:
# 30

# %%
qtde_NulosPorColuna/df_DividaGovCentr.shape[0] * 100
# Out:
# country_name       0.000000
# indicator_name     0.000000
# 1950              82.658960
# 1951              81.502890
# 1952              81.502890
#                     ...
# 2018               1.734104
# 2019               2.312139
# 2020               2.890173
# 2021               4.624277
# 2022               6.936416
# Length: 75, dtype: float64

# %% [markdown]
# ### Vou verificar como fica o Data Set com matriz Transposta.
#
# Acredito, que pelo data set ter países por % da divida, o ideal é que os países sejam as colunas.

# %%
# Verificando se é possivel deletar a coluna 'indicator_name'
df_DividaGovCentr['indicator_name'].unique()
len(df_DividaGovCentr['indicator_name'].unique())
# Out:
# 1

# %%
df_DividaGovCentr_semColumnIN = df_DividaGovCentr.drop(columns=['indicator_name'])
df_DividaGovCentr_semColumnIN.head()
# Out:
#           country_name  1950  1951  1952  1953  1954  1955  1956  1957  1958  \
# 0          Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2              Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...       2013        2014       2015       2016       2017       2018  \
# 0  ...   6.904479    8.700291   9.154083   8.437266   7.997660   7.384413
# 1  ...  65.530002   70.030002  72.670076  72.380044  70.119932  67.610017
# 2  ...   7.093511    7.658320   8.733314  20.438287  27.241982  38.366454
# 3  ...  33.149104   39.809857  57.093048  75.662637  69.322868  92.995001
# 4  ...  95.791048  101.369132  99.071288  86.125894  92.192732  87.699587
#
#          2019        2020        2021       2022
# ...

# %% [markdown]
# # Divida dos Governos Centrais Transposto

# %%
dfT_DividaGovCentr = df_DividaGovCentr_semColumnIN.T
dfT_DividaGovCentr.head()
# Out:
#                       0        1        2       3                    4    \
# country_name  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda
# 1950                  NaN      NaN      NaN     NaN                  NaN
# 1951                  NaN      NaN      NaN     NaN                  NaN
# 1952                  NaN      NaN      NaN     NaN                  NaN
# 1953                  NaN      NaN      NaN     NaN                  NaN
#
#                     5        6           7          8           9    ...  \
# country_name  Argentina  Armenia   Australia    Austria  Azerbaijan  ...
# 1950               20.5      NaN  109.598544  20.926788         NaN  ...
# 1951               17.4      NaN   86.927242  14.439416         NaN  ...
# 1952               18.7      NaN   85.901176  12.841726         NaN  ...
# 1953               21.4      NaN   79.711667  15.711377         NaN  ...
#
#                          163            164      165      166        167  \
# ...

# %%
# Novo indice das colunas
dfT_DividaGovCentr.columns = dfT_DividaGovCentr.iloc[0]

# Removendo a primeira linha que ficou duplicada, uma como cabeçalho e outra como primeira linha
dfT_DividaGovCentr = dfT_DividaGovCentr.iloc[1:]

dfT_DividaGovCentr.head()
# Out:
# country_name Afghanistan Albania Algeria Angola Antigua and Barbuda Argentina  \
# 1950                 NaN     NaN     NaN    NaN                 NaN      20.5
# 1951                 NaN     NaN     NaN    NaN                 NaN      17.4
# 1952                 NaN     NaN     NaN    NaN                 NaN      18.7
# 1953                 NaN     NaN     NaN    NaN                 NaN      21.4
# 1954                 NaN     NaN     NaN    NaN                 NaN      23.9
#
# country_name Armenia   Australia    Austria Azerbaijan  ... United Kingdom  \
# 1950             NaN  109.598544  20.926788        NaN  ...            NaN
# 1951             NaN   86.927242  14.439416        NaN  ...            NaN
# 1952             NaN   85.901176  12.841726        NaN  ...            NaN
# 1953             NaN   79.711667  15.711377        NaN  ...            NaN
# 1954             NaN   76.699146  13.668105        NaN  ...            NaN
#
# ...

# %%
# Renomear a primeira coluna de índice de coluna para 'Ano' diretamente no DataFrame
dfT_DividaGovCentr.columns = ['Ano' if x == 'country_name' else x for x in dfT_DividaGovCentr.columns]



dfT_DividaGovCentr.head()

#print(type(dfT_DividaGovCentr))
# Out:
#      Afghanistan Albania Algeria Angola Antigua and Barbuda Argentina Armenia  \
# 1950         NaN     NaN     NaN    NaN                 NaN      20.5     NaN
# 1951         NaN     NaN     NaN    NaN                 NaN      17.4     NaN
# 1952         NaN     NaN     NaN    NaN                 NaN      18.7     NaN
# 1953         NaN     NaN     NaN    NaN                 NaN      21.4     NaN
# 1954         NaN     NaN     NaN    NaN                 NaN      23.9     NaN
#
#        Australia    Austria Azerbaijan  ... United Kingdom United States  \
# 1950  109.598544  20.926788        NaN  ...            NaN     78.199645
# 1951   86.927242  14.439416        NaN  ...            NaN     68.201929
# 1952   85.901176  12.841726        NaN  ...            NaN     66.341449
# 1953   79.711667  15.711377        NaN  ...            NaN     64.602206
# 1954   76.699146  13.668105        NaN  ...            NaN     64.955715
#
# ...

# %%
dfT_DividaGovCentr.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 dfT_DividaGovCentr.columns()
#
# TypeError: 'Index' object is not callable

# %% [markdown]
# ### Anotação final do dia.
#
# Não consegui terminar a tabela transposta, acredito que falte criar novos indices para poder conseguir mudar nome do indice da primeira coluna para 'Ano'
